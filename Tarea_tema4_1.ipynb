# %%
tabla_periodica = [
    {"Número Atómico": 1, "Símbolo": "H", "Nombre": "Hidrógeno", "Masa Atómica": 1.008, "Carga Eléctrica": 0, "Estado": "Gas", "Tipo": "No metal"},
    {"Número Atómico": 2, "Símbolo": "He", "Nombre": "Helio", "Masa Atómica": 4.0026, "Carga Eléctrica": 0, "Estado": "Gas", "Tipo": "Gas noble"},
    {"Número Atómico": 3, "Símbolo": "Li", "Nombre": "Litio", "Masa Atómica": 6.94, "Carga Eléctrica": +1, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 4, "Símbolo": "Be", "Nombre": "Berilio", "Masa Atómica": 9.0122, "Carga Eléctrica": +2, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 5, "Símbolo": "B", "Nombre": "Boro", "Masa Atómica": 10.81, "Carga Eléctrica": 0, "Estado": "Sólido", "Tipo": "Metaloide"},
    {"Número Atómico": 6, "Símbolo": "C", "Nombre": "Carbono", "Masa Atómica": 12.011, "Carga Eléctrica": 0, "Estado": "Sólido", "Tipo": "No metal"},
    {"Número Atómico": 7, "Símbolo": "N", "Nombre": "Nitrógeno", "Masa Atómica": 14.007, "Carga Eléctrica": 0, "Estado": "Gas", "Tipo": "No metal"},
    {"Número Atómico": 8, "Símbolo": "O", "Nombre": "Oxígeno", "Masa Atómica": 15.999, "Carga Eléctrica": 0, "Estado": "Gas", "Tipo": "No metal"},
    {"Número Atómico": 9, "Símbolo": "F", "Nombre": "Flúor", "Masa Atómica": 18.998, "Carga Eléctrica": -1, "Estado": "Gas", "Tipo": "No metal"},
    {"Número Atómico": 10, "Símbolo": "Ne", "Nombre": "Neón", "Masa Atómica": 20.1797, "Carga Eléctrica": 0, "Estado": "Gas", "Tipo": "Gas noble"},
    {"Número Atómico": 11, "Símbolo": "Na", "Nombre": "Sodio", "Masa Atómica": 22.9897, "Carga Eléctrica": +1, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 12, "Símbolo": "Mg", "Nombre": "Magnesio", "Masa Atómica": 24.305, "Carga Eléctrica": +2, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 13, "Símbolo": "Al", "Nombre": "Aluminio", "Masa Atómica": 26.9815, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 14, "Símbolo": "Si", "Nombre": "Silicio", "Masa Atómica": 28.085, "Carga Eléctrica": 0, "Estado": "Sólido", "Tipo": "Metaloide"},
    {"Número Atómico": 15, "Símbolo": "P", "Nombre": "Fósforo", "Masa Atómica": 30.9738, "Carga Eléctrica": 0, "Estado": "Sólido", "Tipo": "No metal"},
    {"Número Atómico": 16, "Símbolo": "S", "Nombre": "Azufre", "Masa Atómica": 32.06, "Carga Eléctrica": 0, "Estado": "Sólido", "Tipo": "No metal"},
    {"Número Atómico": 17, "Símbolo": "Cl", "Nombre": "Cloro", "Masa Atómica": 35.45, "Carga Eléctrica": -1, "Estado": "Gas", "Tipo": "No metal"},
    {"Número Atómico": 18, "Símbolo": "Ar", "Nombre": "Argón", "Masa Atómica": 39.948, "Carga Eléctrica": 0, "Estado": "Gas", "Tipo": "Gas noble"},
    {"Número Atómico": 19, "Símbolo": "K", "Nombre": "Potasio", "Masa Atómica": 39.0983, "Carga Eléctrica": +1, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 20, "Símbolo": "Ca", "Nombre": "Calcio", "Masa Atómica": 40.078, "Carga Eléctrica": +2, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 21, "Símbolo": "Sc", "Nombre": "Escandio", "Masa Atómica": 44.9559, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 22, "Símbolo": "Ti", "Nombre": "Titanio", "Masa Atómica": 47.867, "Carga Eléctrica": +4, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 23, "Símbolo": "V", "Nombre": "Vanadio", "Masa Atómica": 50.9415, "Carga Eléctrica": +5, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 24, "Símbolo": "Cr", "Nombre": "Cromo", "Masa Atómica": 51.9961, "Carga Eléctrica": +6, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 25, "Símbolo": "Mn", "Nombre": "Manganeso", "Masa Atómica": 54.938, "Carga Eléctrica": +7, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 26, "Símbolo": "Fe", "Nombre": "Hierro", "Masa Atómica": 55.845, "Carga Eléctrica": +2, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 27, "Símbolo": "Co", "Nombre": "Cobalto", "Masa Atómica": 58.9332, "Carga Eléctrica": +2, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 28, "Símbolo": "Ni", "Nombre": "Níquel", "Masa Atómica": 58.6934, "Carga Eléctrica": +2, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 29, "Símbolo": "Cu", "Nombre": "Cobre", "Masa Atómica": 63.546, "Carga Eléctrica": +1, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 30, "Símbolo": "Zn", "Nombre": "Zinc", "Masa Atómica": 65.38, "Carga Eléctrica": +2, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 31, "Símbolo": "Ga", "Nombre": "Galio", "Masa Atómica": 69.723, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 32, "Símbolo": "Ge", "Nombre": "Germanio", "Masa Atómica": 72.630, "Carga Eléctrica": 0, "Estado": "Sólido", "Tipo": "Metaloide"},
    {"Número Atómico": 33, "Símbolo": "As", "Nombre": "Arsénico", "Masa Atómica": 74.9216, "Carga Eléctrica": 0, "Estado": "Sólido", "Tipo": "Metaloide"},
    {"Número Atómico": 34, "Símbolo": "Se", "Nombre": "Selenio", "Masa Atómica": 78.971, "Carga Eléctrica": 0, "Estado": "Sólido", "Tipo": "No metal"},
    {"Número Atómico": 35, "Símbolo": "Br", "Nombre": "Bromo", "Masa Atómica": 79.904, "Carga Eléctrica": -1, "Estado": "Líquido", "Tipo": "No metal"},
    {"Número Atómico": 36, "Símbolo": "Kr", "Nombre": "Kriptón", "Masa Atómica": 83.798, "Carga Eléctrica": 0, "Estado": "Gas", "Tipo": "Gas noble"},
    {"Número Atómico": 37, "Símbolo": "Rb", "Nombre": "Rubidio", "Masa Atómica": 85.4678, "Carga Eléctrica": +1, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 38, "Símbolo": "Sr", "Nombre": "Estroncio", "Masa Atómica": 87.62, "Carga Eléctrica": +2, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 39, "Símbolo": "Y", "Nombre": "Itrio", "Masa Atómica": 88.9059, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 40, "Símbolo": "Zr", "Nombre": "Zirconio", "Masa Atómica": 91.224, "Carga Eléctrica": +4, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 41, "Símbolo": "Nb", "Nombre": "Niobio", "Masa Atómica": 92.9064, "Carga Eléctrica": +5, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 42, "Símbolo": "Mo", "Nombre": "Molibdeno", "Masa Atómica": 95.95, "Carga Eléctrica": +6, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 43, "Símbolo": "Tc", "Nombre": "Tecnecio", "Masa Atómica": 98, "Carga Eléctrica": +7, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 44, "Símbolo": "Ru", "Nombre": "Rutenio", "Masa Atómica": 101.07, "Carga Eléctrica": +4, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 45, "Símbolo": "Rh", "Nombre": "Rutenio", "Masa Atómica": 102.9055, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 46, "Símbolo": "Pd", "Nombre": "Paladio", "Masa Atómica": 106.42, "Carga Eléctrica": +2, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 47, "Símbolo": "Ag", "Nombre": "Plata", "Masa Atómica": 107.8682, "Carga Eléctrica": +1, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 48, "Símbolo": "Cd", "Nombre": "Cadmio", "Masa Atómica": 112.414, "Carga Eléctrica": +2, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 49, "Símbolo": "In", "Nombre": "Indio", "Masa Atómica": 114.818, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 50, "Símbolo": "Sn", "Nombre": "Estaño", "Masa Atómica": 118.710, "Carga Eléctrica": +4, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 51, "Símbolo": "Sb", "Nombre": "Antimonio", "Masa Atómica": 121.760, "Carga Eléctrica": 0, "Estado": "Sólido", "Tipo": "Metaloide"},
    {"Número Atómico": 52, "Símbolo": "Te", "Nombre": "Telurio", "Masa Atómica": 127.60, "Carga Eléctrica": 0, "Estado": "Sólido", "Tipo": "Metaloide"},
    {"Número Atómico": 53, "Símbolo": "I", "Nombre": "Yodo", "Masa Atómica": 126.9044, "Carga Eléctrica": -1, "Estado": "Sólido", "Tipo": "No metal"},
    {"Número Atómico": 54, "Símbolo": "Xe", "Nombre": "Xenón", "Masa Atómica": 131.293, "Carga Eléctrica": 0, "Estado": "Gas", "Tipo": "Gas noble"},
    {"Número Atómico": 55, "Símbolo": "Cs", "Nombre": "Cesio", "Masa Atómica": 132.9055, "Carga Eléctrica": +1, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 56, "Símbolo": "Ba", "Nombre": "Bario", "Masa Atómica": 137.327, "Carga Eléctrica": +2, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 57, "Símbolo": "La", "Nombre": "Lantano", "Masa Atómica": 138.904, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 58, "Símbolo": "Ce", "Nombre": "Cerio", "Masa Atómica": 140.116, "Carga Eléctrica": +4, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 59, "Símbolo": "Pr", "Nombre": "Praseodimio", "Masa Atómica": 140.90766, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 60, "Símbolo": "Nd", "Nombre": "Neodimio", "Masa Atómica": 144.242, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 61, "Símbolo": "Pm", "Nombre": "Prometio", "Masa Atómica": 145, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 62, "Símbolo": "Sm", "Nombre": "Samario", "Masa Atómica": 150.36, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 63, "Símbolo": "Eu", "Nombre": "Europio", "Masa Atómica": 151.964, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 64, "Símbolo": "Gd", "Nombre": "Gadolinio", "Masa Atómica": 157.25, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 65, "Símbolo": "Tb", "Nombre": "Terbio", "Masa Atómica": 158.92535, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 66, "Símbolo": "Dy", "Nombre": "Disprosio", "Masa Atómica": 162.500, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 67, "Símbolo": "Ho", "Nombre": "Holmio", "Masa Atómica": 164.930, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Lantánido"},
    {"Número Atómico": 68, "Símbolo": "Er", "Nombre": "Erbio", "Masa Atómica": 167.259, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Lantánido"},
    {"Número Atómico": 69, "Símbolo": "Tm", "Nombre": "Tulio", "Masa Atómica": 168.934, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Lantánido"},
    {"Número Atómico": 70, "Símbolo": "Yb", "Nombre": "Iterbio", "Masa Atómica": 173.045, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Lantánido"},
    {"Número Atómico": 71, "Símbolo": "Lu", "Nombre": "Lutecio", "Masa Atómica": 174.967, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Lantánido"},
    {"Número Atómico": 72, "Símbolo": "Hf", "Nombre": "Hafnio", "Masa Atómica": 178.49, "Carga Eléctrica": +4, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 73, "Símbolo": "Ta", "Nombre": "Tantalio", "Masa Atómica": 180.948, "Carga Eléctrica": +5, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 74, "Símbolo": "W", "Nombre": "Wolframio", "Masa Atómica": 183.84, "Carga Eléctrica": +6, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 75, "Símbolo": "Re", "Nombre": "Renio", "Masa Atómica": 186.207, "Carga Eléctrica": +7, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 76, "Símbolo": "Os", "Nombre": "Osmio", "Masa Atómica": 190.23, "Carga Eléctrica": +4, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 77, "Símbolo": "Ir", "Nombre": "Iridio", "Masa Atómica": 192.217, "Carga Eléctrica": +4, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 78, "Símbolo": "Pt", "Nombre": "Platino", "Masa Atómica": 195.085, "Carga Eléctrica": +2, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 79, "Símbolo": "Au", "Nombre": "Oro", "Masa Atómica": 196.967, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 80, "Símbolo": "Hg", "Nombre": "Mercurio", "Masa Atómica": 200.592, "Carga Eléctrica": +2, "Estado": "Líquido", "Tipo": "Metal"},
    {"Número Atómico": 81, "Símbolo": "Tl", "Nombre": "Talio", "Masa Atómica": 204.38, "Carga Eléctrica": +1, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 82, "Símbolo": "Pb", "Nombre": "Plomo", "Masa Atómica": 207.2, "Carga Eléctrica": +2, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 83, "Símbolo": "Bi", "Nombre": "Bismuto", "Masa Atómica": 208.980, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 84, "Símbolo": "Po", "Nombre": "Polonio", "Masa Atómica": 209, "Carga Eléctrica": 0, "Estado": "Sólido", "Tipo": "Metaloide"},
    {"Número Atómico": 85, "Símbolo": "At", "Nombre": "Astato", "Masa Atómica": 210, "Carga Eléctrica": 0, "Estado": "Sólido", "Tipo": "Metaloide"},
    {"Número Atómico": 86, "Símbolo": "Rn", "Nombre": "Radón", "Masa Atómica": 222, "Carga Eléctrica": 0, "Estado": "Gas", "Tipo": "Gas noble"},
    {"Número Atómico": 89, "Símbolo": "Ac", "Nombre": "Actinio", "Masa Atómica": 227, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Actínido"},
    {"Número Atómico": 90, "Símbolo": "Th", "Nombre": "Torio", "Masa Atómica": 232.038, "Carga Eléctrica": +4, "Estado": "Sólido", "Tipo": "Actínido"},
    {"Número Atómico": 91, "Símbolo": "Pa", "Nombre": "Protactinio", "Masa Atómica": 231.036, "Carga Eléctrica": +5, "Estado": "Sólido", "Tipo": "Actínido"},
    {"Número Atómico": 92, "Símbolo": "U", "Nombre": "Uranio", "Masa Atómica": 238.029, "Carga Eléctrica": +6, "Estado": "Sólido", "Tipo": "Actínido"},
    {"Número Atómico": 93, "Símbolo": "Np", "Nombre": "Neptunio", "Masa Atómica": 237, "Carga Eléctrica": +5, "Estado": "Sólido", "Tipo": "Actínido"},
    {"Número Atómico": 94, "Símbolo": "Pu", "Nombre": "Plutonio", "Masa Atómica": 244, "Carga Eléctrica": +4, "Estado": "Sólido", "Tipo": "Actínido"},
    {"Número Atómico": 95, "Símbolo": "Am", "Nombre": "Americio", "Masa Atómica": 243, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Actínido"},
    {"Número Atómico": 96, "Símbolo": "Cm", "Nombre": "Curio", "Masa Atómica": 247, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Actínido"},
    {"Número Atómico": 97, "Símbolo": "Bk", "Nombre": "Berkelio", "Masa Atómica": 247, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Actínido"},
    {"Número Atómico": 98, "Símbolo": "Cf", "Nombre": "Californio", "Masa Atómica": 251, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Actínido"},
    {"Número Atómico": 99, "Símbolo": "Es", "Nombre": "Einstenio", "Masa Atómica": 252, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Actínido"},
    {"Número Atómico": 100, "Símbolo": "Fm", "Nombre": "Fermio", "Masa Atómica": 257, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Actínido"},
    {"Número Atómico": 101, "Símbolo": "Md", "Nombre": "Mendelevio", "Masa Atómica": 258, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Actínido"},
    {"Número Atómico": 102, "Símbolo": "No", "Nombre": "Nobelio", "Masa Atómica": 259, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Actínido"},
    {"Número Atómico": 103, "Símbolo": "Lr", "Nombre": "Lawrencio", "Masa Atómica": 262, "Carga Eléctrica": +3, "Estado": "Sólido", "Tipo": "Actínido"},
    {"Número Atómico": 104, "Símbolo": "Rf", "Nombre": "Rutherfordio", "Masa Atómica": 267, "Carga Eléctrica": +4, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 105, "Símbolo": "Db", "Nombre": "Dubnio", "Masa Atómica": 268, "Carga Eléctrica": +5, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 106, "Símbolo": "Sg", "Nombre": "Seaborgio", "Masa Atómica": 269, "Carga Eléctrica": +6, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 107, "Símbolo": "Bh", "Nombre": "Bohrio", "Masa Atómica": 270, "Carga Eléctrica": +7, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 108, "Símbolo": "Hs", "Nombre": "Hassio", "Masa Atómica": 269, "Carga Eléctrica": +8, "Estado": "Sólido", "Tipo": "Metal"},
    {"Número Atómico": 109, "Símbolo": "Mt", "Nombre": "Meitnerio", "Masa Atómica": 278, "Carga Eléctrica": +1, "Estado": "Desconocido", "Tipo": "Metal"},
    {"Número Atómico": 110, "Símbolo": "Ds", "Nombre": "Darmstatio", "Masa Atómica": 281, "Carga Eléctrica": +6, "Estado": "Desconocido", "Tipo": "Metal"},
    {"Número Atómico": 111, "Símbolo": "Rg", "Nombre": "Roentgenio", "Masa Atómica": 282, "Carga Eléctrica": -1, "Estado": "Desconocido", "Tipo": "Metal"},
    {"Número Atómico": 112, "Símbolo": "Cn", "Nombre": "Copernicio", "Masa Atómica": 285, "Carga Eléctrica": +1, "Estado": "Desconocido", "Tipo": "Metal"},
    {"Número Atómico": 113, "Símbolo": "Nh", "Nombre": "Nihonio", "Masa Atómica": 286, "Carga Eléctrica": +1, "Estado": "Desconocido", "Tipo": "Metal"},
    {"Número Atómico": 114, "Símbolo": "Fl", "Nombre": "Flerovio", "Masa Atómica": 289, "Carga Eléctrica": +2, "Estado": "Desconocido", "Tipo": "Metal"},
    {"Número Atómico": 115, "Símbolo": "Mc", "Nombre": "Moscovio", "Masa Atómica": 290, "Carga Eléctrica": +1, "Estado": "Desconocido", "Tipo": "Metal"},
    {"Número Atómico": 116, "Símbolo": "Lv", "Nombre": "Livermorio", "Masa Atómica": 293, "Carga Eléctrica": +2, "Estado": "Desconocido", "Tipo": "Metal"},
    {"Número Atómico": 117, "Símbolo": "Ts", "Nombre": "Tenesino", "Masa Atómica": 294, "Carga Eléctrica": -1, "Estado": "Desconocido", "Tipo": "Metaloide"},
    {"Número Atómico": 118, "Símbolo": "Og", "Nombre": "Oganesón", "Masa Atómica": 294, "Carga Eléctrica": +2, "Estado": "Gas", "Tipo": "Gas noble"}
]
def mostrar_elemento(num_atomico):
    for elemento in tabla_periodica:
        if elemento["Número Atómico"] == num_atomico:
            print("Información del elemento:")
            print(f"Número Atómico: {elemento['Número Atómico']}")
            print(f"Símbolo: {elemento['Símbolo']}")
            print(f"Nombre: {elemento['Nombre']}")
            print(f"Masa Atómica: {elemento['Masa Atómica']}")
            print(f"Carga Eléctrica más común de oxidación: {elemento['Carga Eléctrica']}")
            print(f"Estado: {elemento['Estado']}")
            print(f"Tipo: {elemento['Tipo']}")
            return
    print("Elemento no encontrado.") 
if __name__ == "__main__":
    num_atomico = int(input("Introduce el número atómico del elemento: "))
    mostrar_elemento(num_atomico)
# Out:
# Introduce el número atómico del elemento:  24
# Información del elemento:
# Número Atómico: 24
# Símbolo: Cr
# Nombre: Cromo
# Masa Atómica: 51.9961
# Carga Eléctrica más común de oxidación: 6
# Estado: Sólido
# Tipo: Metal
